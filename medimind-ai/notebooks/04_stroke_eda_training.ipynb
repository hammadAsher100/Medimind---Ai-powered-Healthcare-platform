# %% [markdown]
# # Stroke EDA and Training
# Kaggle Stroke Prediction Dataset pipeline for MediMind AI.

# %%
import os, sys
from pathlib import Path
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
PROJECT = Path('..').resolve()
sys.path.append(str(PROJECT / 'ai_service'))
from ml_models.train_common import run_training, find_target
data_path = PROJECT / 'datasets' / 'stroke.csv'
df = pd.read_csv(data_path)
df.head()

# %%
print('Shape:', df.shape)
display(df.isna().sum())
target = find_target(df, 'stroke')
display(df[target].value_counts())

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.select_dtypes('number').corr(), cmap='coolwarm', center=0)
plt.title('Stroke Correlation Heatmap')
plt.show()

# %% [markdown]
# The training script applies hypertension + heart disease combined flag, preprocessing, SMOTE, four model families, StratifiedKFold metrics, SHAP, MLflow, and artifact export.

# %%
os.environ.setdefault('MLFLOW_TRACKING_URI', 'http://localhost:5000')
result = run_training(str(data_path), 'stroke')
result
